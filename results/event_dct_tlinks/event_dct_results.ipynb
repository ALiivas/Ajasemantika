# %% [markdown]
# ## Event-document creation time (DCT) TLINKs identification results

# %%
import os
from collections import OrderedDict

# %% [markdown]
# #### Importing and organizing model training results

# %%
estbert_ev_dct_path = "estbert_ev_dct_res/estbert_ev_dct_accuracy.txt"
estbert_ev_dct_agg_path = "estbert_ev_dct_agg_res/estbert_ev_dct_agg_accuracy.txt"

estroberta_ev_dct_path = "estroberta_ev_dct_res/estroberta_ev_dct_accuracy.txt"
estroberta_ev_dct_agg_path = "estroberta_ev_dct_agg_res/estroberta_ev_dct_agg_accuracy.txt"

# %%
estbert_ev_dct_res = {}
estbert_ev_dct_agg_res = {}

estroberta_ev_dct_res = {}
estroberta_ev_dct_agg_res = {}

with open(f"{estbert_ev_dct_path}") as f:
    for line in f:
       (key, val) = line.split(": ")
       estbert_ev_dct_res[key] = float(val)
       
with open(f"{estbert_ev_dct_agg_path}") as f:
    for line in f:
       (key, val) = line.split(": ")
       estbert_ev_dct_agg_res[key] = float(val)
       
       
with open(f"{estroberta_ev_dct_path}") as f:
    for line in f:
       (key, val) = line.split(": ")
       estroberta_ev_dct_res[key] = float(val)
       
with open(f"{estroberta_ev_dct_agg_path}") as f:
    for line in f:
       (key, val) = line.split(": ")
       estroberta_ev_dct_agg_res[key] = float(val)

# %% [markdown]
# ### EstBERT results

# %% [markdown]
# #### All TLINK classes

# %%
estbert_ev_dct_res_desc = OrderedDict(sorted(estbert_ev_dct_res.items(), 
                                  key=lambda kv: kv[1], reverse=True))

# sorted
for key, value in dict(estbert_ev_dct_res_desc).items():
    print(key, value)
# Out:
# MLP, mean_penult accuracy 0.6990595611285266
# MLP, avg_penult accuracy 0.6990595611285266
# MLP, mean_add accuracy 0.6833855799373041
# MLP, avg_add accuracy 0.6833855799373041
# MLP, main_penult accuracy 0.6802507836990596
# MLP, main_add accuracy 0.677115987460815
# MLP, mean_concat accuracy 0.6739811912225705
# MLP, avg_concat accuracy 0.6739811912225705
# XGB, mean_concat accuracy 0.6677115987460815
# XGB, avg_concat accuracy 0.6677115987460815
# MLP, main_concat accuracy 0.6551724137931034
# XGB, mean_penult accuracy 0.6551724137931034
# XGB, avg_penult accuracy 0.6551724137931034
# MLP, mean_last accuracy 0.6489028213166145
# MLP, avg_last accuracy 0.6489028213166145
# XGB, main_penult accuracy 0.6394984326018809
# MLP, main_last accuracy 0.6394984326018809
# XGB, main_concat accuracy 0.6363636363636364
# XGB, mean_add accuracy 0.6332288401253918
# XGB, avg_add accuracy 0.6332288401253918
# XGB, main_add accuracy 0.6300940438871473
# XGB, mean_last accuracy 0.6269592476489029
# ...

# %% [markdown]
# #### TLINKs aggregated into 4 classes

# %%
estbert_ev_dct_agg_res_desc = OrderedDict(sorted(estbert_ev_dct_agg_res.items(), 
                                  key=lambda kv: kv[1], reverse=True))

# sorted
for key, value in dict(estbert_ev_dct_agg_res_desc).items():
    print(key, value)
# Out:
# MLP, mean_concat accuracy 0.6896551724137931
# MLP, avg_concat accuracy 0.6896551724137931
# MLP, main_add accuracy 0.6551724137931034
# MLP, main_concat accuracy 0.6520376175548589
# MLP, mean_penult accuracy 0.6520376175548589
# MLP, avg_penult accuracy 0.6520376175548589
# MLP, mean_last accuracy 0.6489028213166145
# MLP, avg_last accuracy 0.6489028213166145
# MLP, mean_add accuracy 0.64576802507837
# MLP, avg_add accuracy 0.64576802507837
# MLP, main_penult accuracy 0.64576802507837
# XGB, main_penult accuracy 0.64576802507837
# MLP, main_last accuracy 0.64576802507837
# XGB, mean_last accuracy 0.6426332288401254
# XGB, avg_last accuracy 0.6426332288401254
# XGB, mean_add accuracy 0.6394984326018809
# XGB, avg_add accuracy 0.6394984326018809
# XGB, mean_concat accuracy 0.6332288401253918
# XGB, avg_concat accuracy 0.6332288401253918
# XGB, mean_penult accuracy 0.6332288401253918
# XGB, avg_penult accuracy 0.6332288401253918
# XGB, main_concat accuracy 0.6206896551724138
# ...

# %% [markdown]
# ### Est-RoBERTa results

# %% [markdown]
# #### All TLINK classes

# %%
estroberta_ev_dct_res_desc = OrderedDict(sorted(estroberta_ev_dct_res.items(), 
                                  key=lambda kv: kv[1], reverse=True))

# sorted
for key, value in dict(estroberta_ev_dct_res_desc).items():
    print(key, value)
# Out:
# MLP, main_add accuracy 0.6739811912225705
# MLP, main_penult accuracy 0.6677115987460815
# MLP, mean_penult accuracy 0.658307210031348
# MLP, avg_penult accuracy 0.658307210031348
# SVC, mean_add accuracy 0.6551724137931034
# SVC, avg_add accuracy 0.6551724137931034
# SVC, main_concat accuracy 0.6489028213166145
# MLP, mean_add accuracy 0.6489028213166145
# MLP, avg_add accuracy 0.6489028213166145
# SVC, mean_concat accuracy 0.64576802507837
# SVC, avg_concat accuracy 0.64576802507837
# MLP, main_last accuracy 0.64576802507837
# XGB, main_last accuracy 0.6426332288401254
# XGB, mean_last accuracy 0.6426332288401254
# XGB, avg_last accuracy 0.6426332288401254
# MLP, main_concat accuracy 0.6363636363636364
# MLP, mean_concat accuracy 0.6363636363636364
# XGB, mean_concat accuracy 0.6363636363636364
# MLP, avg_concat accuracy 0.6363636363636364
# XGB, avg_concat accuracy 0.6363636363636364
# XGB, main_penult accuracy 0.6332288401253918
# MLP, mean_last accuracy 0.6300940438871473
# ...

# %% [markdown]
# #### TLINKs aggregated into 4 classes

# %%
estroberta_ev_dct_agg_res_desc = OrderedDict(sorted(estroberta_ev_dct_agg_res.items(), 
                                  key=lambda kv: kv[1], reverse=True))

# sorted
for key, value in dict(estroberta_ev_dct_agg_res_desc).items():
    print(key, value)
# Out:
# MLP, mean_concat accuracy 0.6802507836990596
# MLP, avg_concat accuracy 0.6802507836990596
# MLP, main_concat accuracy 0.677115987460815
# MLP, main_add accuracy 0.6614420062695925
# SVC, main_concat accuracy 0.6520376175548589
# MLP, mean_add accuracy 0.6520376175548589
# MLP, avg_add accuracy 0.6520376175548589
# MLP, mean_last accuracy 0.6520376175548589
# MLP, avg_last accuracy 0.6520376175548589
# MLP, mean_penult accuracy 0.6489028213166145
# MLP, avg_penult accuracy 0.6489028213166145
# XGB, main_concat accuracy 0.64576802507837
# SVC, mean_concat accuracy 0.64576802507837
# SVC, avg_concat accuracy 0.64576802507837
# MLP, main_penult accuracy 0.64576802507837
# SVC, mean_add accuracy 0.6426332288401254
# SVC, avg_add accuracy 0.6426332288401254
# MLP, main_last accuracy 0.6426332288401254
# XGB, mean_add accuracy 0.6394984326018809
# XGB, avg_add accuracy 0.6394984326018809
# XGB, mean_last accuracy 0.6363636363636364
# XGB, avg_last accuracy 0.6363636363636364
# ...
